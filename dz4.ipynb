# %%
documents = [
        {"type": "passport", "number": "2207 876234", "name": "Василий Гупкин"},
        {"type": "invoice", "number": "11-2", "name": "Геннадий Покемонов"},
        {"type": "insurance", "number": "10006", "name": "Аристарх Павлов"}
      ]
 
directories = {
        '1': ['2207 876234', '11-2'],
        '2': ['10006'],
        '3': []
      }

def people(numbers):
    for doc_numbers in documents:
        if doc_numbers["number"] == numbers:
            print(doc_numbers["name"])
            break
    else:
        print('Документ не найден в базе.')
        
def shelf(numbers):
    break_marker = False
    for shelf_directories in directories.items():
        for doc_numbers in shelf_directories[1]:
            if doc_numbers == numbers:
                print('Документ хранится на полке:', shelf_directories[0])
                break_marker = True
                break
        if break_marker == True:
            break
    else:
        print('Документ не найден в базе.')
        
def people_list():
    for x in documents:
        type = x['type']
        number = x['number']
        name = x['name']
        print('{0}"{1}" "{2}"'.format(type, number, name))
        
def add_shelf(shelf):
    for direct in directories.items():
        if shelf in direct[0]:
            print(f"Такая полка уже существует. Текущий перечень полок: {list(directories.keys())}")
            break
    else:
        directories[shelf] = []
        print(f"Полка добавлена. Текущий перечень полок: {list(directories.keys())}")
        
def delete_document(data_documents, data_directories, delete_number):
    i=0
    for row in data_documents:
        if delete_number== row['number']:
            i+=1
            data_documents.remove(row)
    for row in data_directories.items():
        if delete_number in row[1]:
            list_documents=row[1]
            list_documents.remove(delete_number)
            data_directories.setdefault(row[0], list_documents)
    if i==0:
        print('Удаление невозможно, номер документа введен некорректно!')
    else:
        print('Документ удален.Список документов после удаления:')
        for row in data_documents:
            print(row)
        print('Перечень полок хранения документов:')
        for row in data_directories.items():
            print(row)
            
def add_new_doc(params_type, number, name, directories_number):
    if int(directories_number) == 1 or int(directories_number) == 2 or int(directories_number) == 3:
        documents.append({"type": params_type, "number": number, "name": name})
        directories[directories_number].append(number)
    else:
        print('Такой полки не существует. Добавьте полку командой as.')
    print(documents)
    print(directories)
    
def move_document(data, shelf, number_document):
    i=0
    if shelf not in data.keys():
        print('Такой полки не существует.')
    else:
        for row in data.items():
            if number_document in row[1]:
                list_documents=row[1]
                list_documents.remove(number_document)
                data.setdefault(row[0], list_documents)
                i+=1
    if i==0:
        print('Документ не найден в базе.')
    else:
        for row in data.items():
            if move_shelf==row[0]:
                list_documents=row[1]
                list_documents.append(number_document)
                data.setdefault(row[0], list_documents)
        derictories=data
        print(directories)
        
while True:
    command = input('\n \
    Введите одну из команд: p, l, s, ads, d, ad, m. \n \
    Для выхода наберите exit. \n \
    Для вызов справки наберите help. \n \
    Ваша команда: ')
    if command == 'p':
        people(input('\nВведите номер документа:'))
    elif command == 'l':
        people_list()
    elif command == 's':
        shelf(input('\nВведите номер документа:'))
    elif command == 'ads':
        add_shelf(input('\nВведите номер полки:'))
    elif command == 'd':
        delete =(input('\nВведите номер документа:'))
        delete_document(documents, directories, delete)
    elif command == 'ad':
        add_new_doc(input('\nВведите тип документа:'), input('Введите номер документа:'), input('Введите имя:'), input('Введите номер полки (1, 2, 3):'))
    elif command == 'm':
        move_number_document=input('Введите номер документа:')
        move_shelf= input('Введите номер полки:')
        move_document(directories, move_shelf, move_number_document)   
    elif command == 'exit':
        break
    elif command == 'help':
        print('\n \
        p – people – команда, которая спросит номер документа и выведет имя человека, которому он принадлежит;\n \
        l – people_list – команда, которая выведет список всех документов в формате passport "2207 876234" "Василий Гупкин";\n \
        s – shelf – команда, которая спросит номер документа и выведет номер полки, на которой он находится;\n \
        ads – add_shelf – команда, которая спросит номер полки, которую необходимо добавить и выведет список всех полок;\n \
        d – delete_document – команда, которая спросит номер документа, который необходимо удалить и выведет список всех документов;\n \
        m – move_document – команда, которая спросит номер документа и номер полки на которую необходимо перенести документ;\n \
        ad – add_new_doc – команда, которая добавит новый документ в каталог и в перечень полок, спросив его номер, тип, имя владельца и номер полки, на котором он будет храниться.')
    else:
        print('Вы ввели некорректную команду, повторите ввод.')
# Out:
#      Введите одну из команд: p, l, s, ads, d, ad, m.
#      Для выхода наберите exit.
#      Для вызов справки наберите help.
#      Ваша команда: exit

# %%
m
